# %%
# Set up for running selenium in Google Colab
## You don't need to run this code if you do it in Jupyter notebook, or other local Python setting
# %%shell
sudo apt -y update
sudo apt install -y wget curl unzip
wget http://archive.ubuntu.com/ubuntu/pool/main/libu/libu2f-host/libu2f-udev_1.1.4-1_all.deb
dpkg -i libu2f-udev_1.1.4-1_all.deb
wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
dpkg -i google-chrome-stable_current_amd64.deb
CHROME_DRIVER_VERSION=`curl -sS chromedriver.storage.googleapis.com/LATEST_RELEASE`
wget -N https://chromedriver.storage.googleapis.com/$CHROME_DRIVER_VERSION/chromedriver_linux64.zip -P /tmp/
unzip -o /tmp/chromedriver_linux64.zip -d /tmp/
chmod +x /tmp/chromedriver
mv /tmp/chromedriver /usr/local/bin/chromedriver
pip install selenium
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 20 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# ...

# %%
# !pip install chromedriver-autoinstaller

# %%
import sys
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')

import time
import pandas as pd
from bs4 import BeautifulSoup
import selenium
from selenium import webdriver
import chromedriver_autoinstaller

print(selenium.__version__)
# Out:
# 4.14.0

# %%
# setup chrome options
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless') # ensure GUI is off
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# set path to chromedriver as per your configuration
chromedriver_autoinstaller.install()

# set up the webdriver
driver = webdriver.Chrome(options=chrome_options)
print(driver)
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="5d25588e586e0651c38ad8ffab9343c2")>

# %%
# 필요한 라이브러리 import
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# 해당 URL로 이동
url = "https://www.xn--2z1bw8k1pjz5ccumkb.kr/edc/crse/place.do?punit=5&psize=12&m1=&m2=&m3=&m4=&pno=1&sch_area_cd=101&sch_signgu_cd=&sch_oper_sttus_se_cd=&sch_edc_plc_se_cd=&sch_edc_place_nm=#"
driver.get(url)

# 페이지 스크롤 다운 (모든 장소 정보를 로드하기 위해)
for i in range(3):  # 예를 들어 3번 스크롤 다운
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)  # 스크롤 후 로딩을 위해 잠시 대기

# 장소 이름 추출
place_names = []
elements = driver.find_elements(By.XPATH, "//p[@class='title ellip']")
for element in elements:
    place_names.append(element.text)

# 장소 이름 출력
for place_name in place_names:
    print(place_name)

# WebDriver 종료
#driver.quit()
# Out:
# 서울시민대학 동남권캠퍼스
# 스마트 구로 홍보관
# 은평구립도서관
# 헬리오시티APT경로당
# 강서구립곰달래어르신복지센터
# 자양한강도서관
# 강동구립해공도서관
# 성현동주민센터(정보화교육장)
# 도봉동어르신복지관
# 관악삼성동주민자치회관
# 금천 구청 교육장
# 성산1동주민센터

# %%
# 필요한 라이브러리 import
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# 해당 URL로 이동
url = "https://www.xn--2z1bw8k1pjz5ccumkb.kr/edc/crse/place.do?punit=5&psize=12&m1=&m2=&m3=&m4=&pno=1&sch_area_cd=101&sch_signgu_cd=&sch_oper_sttus_se_cd=&sch_edc_plc_se_cd=&sch_edc_place_nm=#"
driver.get(url)

 # 페이지 스크롤 다운 (모든 장소 정보를 로드하기 위해)
for i in range(3):  # 예를 들어 3번 스크롤 다운
  driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
  time.sleep(2)  # 스크롤 후 로딩을 위해 잠시 대기

    # 장소 이름 추출
  elements = driver.find_elements(By.XPATH, "//p[@class='title ellip']")
  place_names.extend(element.text for element in elements)

    # 주소 추출
  addresses = []
  address_elements = driver.find_elements(By.XPATH, "//li[@class='ellip']")
  addresses.extend(element.text for element in address_elements)

# 장소 이름과 주소 출력
for name, address in zip(place_names, addresses):
    print(f"장소: {name}, 주소: {address}")

# WebDriver 종료
#driver.quit()
# Out:
# 장소: 서울시민대학 동남권캠퍼스, 주소: 서울특별시 강동구 고덕로 399 (고덕동, 고덕센트럴푸르지오)
# 장소: 스마트 구로 홍보관, 주소: 서울특별시 구로구 새말로 지하117-21 (신도림동)
# 장소: 은평구립도서관, 주소: 서울특별시 은평구 통일로78가길 13-84 (불광동)
# 장소: 헬리오시티APT경로당, 주소: 서울특별시 송파구 송파대로 345 (가락동, 헬리오시티)
# 장소: 강서구립곰달래어르신복지센터, 주소: 서울특별시 강서구 강서로5길 50 (화곡동)
# 장소: 자양한강도서관, 주소: 서울특별시 광진구 뚝섬로52길 66 (자양동)
# 장소: 강동구립해공도서관, 주소: 서울특별시 강동구 올림픽로 702 (천호동)
# 장소: 성현동주민센터(정보화교육장), 주소: 서울특별시 관악구 구암길 38(봉천동 1712-9) 성현동주민센터 2층 정보화교육장
# 장소: 도봉동어르신복지관, 주소: 서울특별시 도봉구 도봉로169가길 52 (도봉동)
# 장소: 관악삼성동주민자치회관, 주소: 서울특별시 관악구 호암로 520 (신림동)
# 장소: 금천 구청 교육장, 주소: 서울특별시 금천구 시흥대로73길 70 (시흥동)
# 장소: 성산1동주민센터, 주소: 서울특별시 마포구 성산로4길 15 (성산동)

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# 1부터 15까지 반복
for m in range(1, 16):
    # URL 생성
    url = f"https://www.xn--2z1bw8k1pjz5ccumkb.kr/edc/crse/place.do?punit=5&psize=12&m1=&m2=&m3=&m4=&pno={m}&sch_area_cd=101&sch_signgu_cd=&sch_oper_sttus_se_cd=&sch_edc_plc_se_cd=&sch_edc_place_nm=#"

    # 해당 URL로 이동
    driver.get(url)

    # 페이지 스크롤 다운 (모든 장소 정보를 로드하기 위해)
    for i in range(3):  # 예를 들어 3번 스크롤 다운
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
        time.sleep(2)  # 스크롤 후 로딩을 위해 잠시 대기

    # 장소명과 주소를 저장할 리스트 초기화
    place_names = []
    addresses = []

    # 장소 정보 추출
    elements = driver.find_elements(By.XPATH, "//p[@class='title ellip']")
    for element in elements:
        place_names.append(element.text)

    address_elements = driver.find_elements(By.XPATH, "//li[@class='ellip']")
    for element in address_elements:
        addresses.append(element.text)

    # 장소명과 주소 출력
    for name, address in zip(place_names, addresses):
        print(f"장소명: {name}, 주소: {address}")
# Out:
# 장소 이름: 서울시민대학 동남권캠퍼스, 주소: 서울특별시 강동구 고덕로 399 (고덕동, 고덕센트럴푸르지오)
# 장소 이름: 스마트 구로 홍보관, 주소: 서울특별시 구로구 새말로 지하117-21 (신도림동)
# 장소 이름: 은평구립도서관, 주소: 서울특별시 은평구 통일로78가길 13-84 (불광동)
# 장소 이름: 헬리오시티APT경로당, 주소: 서울특별시 송파구 송파대로 345 (가락동, 헬리오시티)
# 장소 이름: 강서구립곰달래어르신복지센터, 주소: 서울특별시 강서구 강서로5길 50 (화곡동)
# 장소 이름: 자양한강도서관, 주소: 서울특별시 광진구 뚝섬로52길 66 (자양동)
# 장소 이름: 강동구립해공도서관, 주소: 서울특별시 강동구 올림픽로 702 (천호동)
# 장소 이름: 성현동주민센터(정보화교육장), 주소: 서울특별시 관악구 구암길 38(봉천동 1712-9) 성현동주민센터 2층 정보화교육장
# 장소 이름: 도봉동어르신복지관, 주소: 서울특별시 도봉구 도봉로169가길 52 (도봉동)
# 장소 이름: 관악삼성동주민자치회관, 주소: 서울특별시 관악구 호암로 520 (신림동)
# 장소 이름: 금천 구청 교육장, 주소: 서울특별시 금천구 시흥대로73길 70 (시흥동)
# 장소 이름: 성산1동주민센터, 주소: 서울특별시 마포구 성산로4길 15 (성산동)
# 장소 이름: 구립갈현노인복지관, 주소: 서울특별시 은평구 통일로89길 12-6 (갈현동)
# 장소 이름: 성산1동주민센터, 주소: 서울특별시 마포구 성산로4길 15 (성산동)
# 장소 이름: 중랑상봉도서관, 주소: 서울특별시 중랑구 동일로114길 10 (상봉동)
# 장소 이름: 창동주공19단지A 경로당, 주소: 서울특별시 도봉구 노해로70길 54 (창동, 주공19단지아파트)
# 장소 이름: 시립강동노인종합복지관, 주소: 서울특별시 강동구 동남로71길 32-5 (명일동)
# 장소 이름: 메리워드지역아동센터, 주소: 서울특별시 구로구 고척로 49 (오류동, 동부골든아파트)
# ...

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

data = []

# 15페이지까지 반복하기
for m in range(1, 16):

    url = f"https://www.xn--2z1bw8k1pjz5ccumkb.kr/edc/crse/place.do?punit=5&psize=12&m1=&m2=&m3=&m4=&pno={m}&sch_area_cd=101&sch_signgu_cd=&sch_oper_sttus_se_cd=&sch_edc_plc_se_cd=&sch_edc_place_nm=#"
    driver.get(url)

    # 페이지 스크롤 다운 (모든 장소 정보를 로드하기 위해)
    for i in range(3):
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
        time.sleep(2)

    # 장소명과 주소명 추출하기
    place_names = []
    addresses = []
    elements = driver.find_elements(By.XPATH, "//p[@class='title ellip']")
    for element in elements:
        place_names.append(element.text)

    address_elements = driver.find_elements(By.XPATH, "//li[@class='ellip']")
    for element in address_elements:
        addresses.append(element.text)

    # 데이터 리스트에 추가
    for name, address in zip(place_names, addresses):
        data.append([name, address])

df = pd.DataFrame(data, columns=["장소명", "주소명"])

df.to_excel("디지털 배움터 주소, 장소 크롤링.xlsx", index=False)
